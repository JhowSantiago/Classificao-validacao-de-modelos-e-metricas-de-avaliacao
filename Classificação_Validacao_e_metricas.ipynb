# %% [markdown]
# # <font color='dark'>**Classificação: Validação de modelos e métricas de avaliação**</h1>

# %% [markdown]
# ### Projeto
#
# Uma empresa de empréstimo de automóveis está passando por uma situação complicada, com alta demanda para uma frota reduzida de veículos e alto número de inadimplentes, trazendo um prejuízo grande para a empresa.
#
# Nós fomos contratados para buscar melhorias na identificação de inadimplentes. A análise dos clientes atualmente é feita de forma manual, cliente por cliente, tomando muito tempo e ainda assim a detecção de inadimplentes é muito imprecisa.
#
# Nossa tarefa é utilizar os dados fornecidos pela empresa para **classificar** os clientes em adimplentes e inadimplentes.

# %% [markdown]
# ## <font color='dark'>Classificando dados</h1>

# %% [markdown]
# ### Criando um modelo inicial

# %%
import pandas as pd

# %%
dados = pd.read_csv('.\\emp_automovel.csv')

# %%
dados
# Out:
#        receita_cliente  anuidade_emprestimo  anos_casa_propria  telefone_trab  \
# 0         12600.000000          3569.400000          12.157324              1
# 1          9000.000000          2722.188351           7.000000              0
# 2         15750.000000          4477.500000          12.000000              0
# 3          9000.000000          1309.050000          12.157324              0
# 4          7650.000000          1125.000000          12.157324              0
# ...                ...                  ...                ...            ...
# 54020     16855.246324           675.000000          12.157324              1
# 54021     11250.000000           675.000000          14.000000              0
# 54022     13500.000000           900.000000          64.000000              0
# 54023     11250.000000          2371.500000          12.157324              0
# 54024     21060.000000          2459.250000          12.157324              0
#
# ...

# %%
x = dados.drop('inadimplente', axis =1)
y = dados['inadimplente']

# %%
import matplotlib.pyplot as plt
y.value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.ylabel('')
plt.title('Distribution of Categories')
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
modelo = DecisionTreeClassifier()
modelo.fit(x, y)
modelo.score(x, y)
# Out:
# 1.0

# %%
print(f'Acurácia: {modelo.score(x,y)}')
# Out:
# Acurácia: 1.0

# %% [markdown]
# ### Validando o modelo

# %% [markdown]
# Avaliar os modelo com base nos mesmos dados usados no treinamento não é interessante. É preciso que a avaliação seja feita em dados independentes.
#
# Avaliar o modelo nos próprios dados de treinamento seria o análogo a entregar uma prova com as questões e o gabarito para uma pessoa e no momento de avaliá-la novamente, entregar uma prova com as mesmas questões e alternativas. É esperado que essa pessoa se sairá bem por já ter visto as respostas e ter decorado o resultado. Isso é diferente de ter aprendido a matéria a partir daquela prova e depois fazer uma prova com conteúdo parecido e ter um resultado positivo.
#
# No intuito de checar a generalização de um modelo, devemos separar o conjunto de dados em 3 partes: dados de treinamento, validação e teste.
#
# - o conjunto de treinamento é utilizado para treinar os modelos. Os modelos vão entender o padrão dos dados a partir desse conjunto de dados.
#
# - o conjunto de validação é utilizado para avaliar o desempenho de diferentes modelos, com dados novos que não foram usados no treinamento do modelo.
#
# - o conjunto de teste fica separado dos demais desde o momento inicial para simular os dados do mundo real. Ele não é utilizado em nenhum momento no treinamento e nem na validação, servindo como uma estimativa da capacidade do modelo escolhido de generalizar e prever novos dados.

# %% [markdown]
# ![2023-07-17_10-06.png](data:image/png;base64,...)

# %%
from sklearn.model_selection import train_test_split

# %%
# fazendo a divisão dos dados em treino e teste separando 15% para teste e utilizando
#stratify para manter a proporção de inadimplentes e não inadimplentes nesses 2 cojunto de dados
# o x e o y vão ser atualizados apos a divisão em teste com 15% a menos de dados
x, x_teste, y, y_teste = train_test_split(x, y, test_size = 0.15, stratify = y, random_state = 5)

# agora após a divisão dos dados para teste os dados que sobraram vão ser divididos em treino e validação
# Por padrão o train_test_split divide 75% para treino e 25% para validação
x_treino, x_val, y_treino, y_val = train_test_split(x, y, stratify = y, random_state = 5)

# %%
print(f'Quantidade total de dados: {len(dados)}')
print(f'Quantidade de dados para teste 15% : {len(x_teste)}')
print(f'Total após divisão para teste: {len(dados) - len(x_teste)}')
print(f'Quantidade de dados para treino 75% : {len(x_treino)}')
print(f'Quantidade de dados para validação 25% : {len(x_val)}')
# Out:
# Quantidade total de dados: 54025
# Quantidade de dados para teste 15% : 8104
# Total após divisão para teste: 45921
# Quantidade de dados para treino 75% : 34440
# Quantidade de dados para validação 25% : 11481

# %%
#criando novamente o modelo utilizando os dados de treino para treinar o modelo
# e utilizando os de validação para testar o modelo
arvore = DecisionTreeClassifier()

#treinando o modelo com o dados de treino
arvore.fit(x_treino, y_treino)

#verificando a acuraácia do modelo com os dados de treino
print(f'Acurácia de treino: {arvore.score(x_treino, y_treino)}')

#verificando a acuraácia do modelo com os dados de validação
print(f'Acurácia de validação: {arvore.score(x_val, y_val)}')
# Out:
# Acurácia de treino: 1.0
# Acurácia de validação: 0.8489678599425137

# %% [markdown]
# ### Ajustando o modelo de árvore passando max_depth para evitar overfitting

# %% [markdown]
# Overfitting é um problema comum em aprendizado de máquina onde um modelo se ajusta excessivamente aos dados de treinamento, capturando não apenas os padrões gerais, mas também os ruídos e detalhes irrelevantes. Como resultado, o modelo apresenta um desempenho excelente nos dados de treinamento, mas tem uma capacidade de generalização pobre, ou seja, não funciona bem em novos dados ou dados de teste.

# %%
# Ajustando o modelo para evitar overfitting com o max_depth pois o modelo estava apenas memorizando os dados
# e não generalizando
arvore = DecisionTreeClassifier(max_depth = 10, random_state=5)

arvore.fit(x_treino, y_treino)
#verificando a acuraácia do modelo com os dados de treino
print(f'Acurácia de treino: {arvore.score(x_treino, y_treino)}')

#verificando a acuraácia do modelo com os dados de validação
print(f'Acurácia de validação: {arvore.score(x_val, y_val)}')
# Out:
# Acurácia de treino: 0.9206445993031359
# Acurácia de validação: 0.905496036930581

# %% [markdown]
# #### Avaliando o modelo com matriz de confusão

# %%
from sklearn.metrics import confusion_matrix

# %%
#armezenando os dados previstos para os dados de validação
y_previsto = arvore.predict(x_val)

#criando a matriz de confusão para verificar a quantidade de acertos e erros do modelo
# Comparando os dados previstos com os dados de validação (dados reais)
matriz_confusao = confusion_matrix(y_val, y_previsto)
print(matriz_confusao)
# Out:
# [[10354   125]
#  [  960    42]]

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# %%
visualizacao = ConfusionMatrixDisplay(confusion_matrix = matriz_confusao, display_labels=['Adimplente', 'Inadimplente'])
visualizacao.plot();

# %% [markdown]
# ### Construindo um segundo modelo   RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
random_forest = RandomForestClassifier(max_depth=8,random_state=5)

#treinando o modelo com o dados de treino
random_forest.fit(x_treino,y_treino)

#verificando a acuraácia do modelo com os dados de treino
print(f'Acurácia de treino: {random_forest.score(x_treino, y_treino)}')

#verificando a acuraácia do modelo com os dados de validação
print(f'Acurácia de validação: {random_forest.score(x_val, y_val)}')
# Out:
# Acurácia de treino: 0.9135017421602788
# Acurácia de validação: 0.9128124727811167

# %% [markdown]
# #### Avaliando o modelo com matriz de confusão

# %%
#armezenando os dados previstos para os dados de validação
y_previsto = random_forest.predict(x_val)

#criando a matriz de confusão para verificar a quantidade de acertos e erros do modelo
# Comparando os dados previstos com os dados de validação (dados reais)
matriz_confusao = confusion_matrix(y_val, y_previsto)
print(matriz_confusao)
# Out:
# [[10479     0]
#  [ 1001     1]]

# %%
visualizacao = ConfusionMatrixDisplay(confusion_matrix = matriz_confusao, display_labels=['Adimplente', 'Inadimplente'])
visualizacao.plot();

# %% [markdown]
# ## <font color='dark'>Métricas de avaliação</h1>

# %% [markdown]
# ### Acurácia, precisão e recall

# %% [markdown]
# ![2023-07-20_10-56.png](data:image/png;base64,...)

# %% [markdown]
# * Verdadeiros Negativos (VN): Quando o valor real for 0 e a predição também for 0. Indica que o modelo classificou corretamente os valores da classe negativa.
#
# * Falsos Positivos (FP): Quando o valor real for 0 e a predição for 1. Indica que o modelo classificou erroneamente um elemento da classe negativa como se fosse da classe positiva.
#
# * Falsos Negativos (FN): Quando o valor real for 1 e a predição for 0. Indica que o modelo classificou erroneamente um elemento da classe positiva como se fosse da classe negativa.
#
# * Verdadeiros Positivos (VP): Quando o valor real for 1 e a predição também for 1. Indica que o modelo classificou corretamente os valores da classe positiva.

# %%
from sklearn.metrics import accuracy_score

# %%
print(f'Acurácia: {accuracy_score(y_val, y_previsto)}')
# Out:
# Acurácia: 0.9056702377841651

# %%
from sklearn.metrics import precision_score, recall_score

# %%
print(f'Precisão: {precision_score(y_val, y_previsto)}')
print(f'Revocação: {recall_score(y_val, y_previsto)}')
# Out:
# Precisão: 0.24528301886792453
# Revocação: 0.038922155688622756

# %%
from sklearn.metrics import f1_score

# %%
print(f'F1-score: {f1_score(y_val, y_previsto)}')
# Out:
# F1-score: 0.06718346253229975

# %% [markdown]
# ### Curva ROC

# %%
from sklearn.metrics import RocCurveDisplay

# %%
RocCurveDisplay.from_predictions(y_val, y_previsto, name = 'Árvore de Decisão');

# %%
from sklearn.metrics import roc_auc_score

# %%
print(f'AUC: {roc_auc_score(y_val, y_previsto)}')
# Out:
# AUC: 0.5137353406556483

# %% [markdown]
# ### Curva de precisão x recall

# %%
from sklearn.metrics import PrecisionRecallDisplay

# %%
PrecisionRecallDisplay.from_predictions(y_val, y_previsto, name = 'Árvore de decisão');

# %%
from sklearn.metrics import average_precision_score

# %%
print(f'AP: {average_precision_score(y_val, y_previsto)}')
# Out:
# AP: 0.09342465484893667

# %% [markdown]
# ### Relatório de métricas

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_val, y_previsto))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95     10479
#            1       0.25      0.04      0.07      1002
#
#     accuracy                           0.91     11481
#    macro avg       0.58      0.51      0.51     11481
# weighted avg       0.86      0.91      0.87     11481

# %% [markdown]
# ## <font color='dark'>Validação cruzada</h1>

# %% [markdown]
# ### Usando o KFold

# %% [markdown]
# A validação do modelo de classificação a partir da separação dos dados em conjunto de treino e validação faz com que o resultado seja muito dependente dessa divisão dos dados e pode ser que, de forma aleatória, o padrão dos dados de validação sejam diferentes do padrão dos dados de treinamento, levando a sorte de ter um resultado muito melhor do que a realidade ou o azar de um resultado muito pior do que a realidade.
#
# Levando isso em consideração, é possível utilizar a **validação cruzada**, uma estratégia mais consistente e bem mais utilizada nos projetos de machine learning.
#
# Na validação cruzada, ao invés de separarmos os dados em apenas treino e validação uma única vez, dividimos os dados em várias partes de mesmo tamanho. Em cada uma dessas divisões, será utilizada uma parte para validação e todas as outras para treinamento e o processo se repete até que todas as partes sejam utilizadas para validação e o restante para treinamento.
#
# Será gerado um modelo para cada uma dessas divisões e a avaliação de desempenho será feita tirando a média da métrica de cada modelo. Isso faz com que a dependência da separação dos dados seja eliminada, já que há uma variação maior da escolha dos dados e é retirada uma média.
#
# Geralmente são utilizadas 5 ou 10 partes, mais do que isso não é tão necessário porque necessita de um processamento maior e valores menores já mitiga o problema da escolha dos dados.

# %% [markdown]
# ![2023-07-17_12-39.png](data:image/png;base64,...)

# %%
from sklearn.model_selection import cross_validate, KFold

# %%
modelo = DecisionTreeClassifier(max_depth = 10)
kf = KFold(n_splits = 5, shuffle = True, random_state = 5)
cv_resultados = cross_validate(modelo, x, y, cv = kf)
cv_resultados
# Out:
# {'fit_time': array([0.23740792, 0.21299005, 0.22075653, 0.21707034, 0.21065998]),
#  'score_time': array([0.00390935, 0.00384569, 0.0039804 , 0.00385022, 0.00543857]),
#  'test_score': array([0.91246598, 0.9070122 , 0.90722997, 0.91310976, 0.89884582])}

# %%
cv_resultados['test_score']
# Out:
# array([0.91246598, 0.9070122 , 0.90722997, 0.91310976, 0.89884582])

# %%
media = cv_resultados['test_score'].mean()
desvio_padrao = cv_resultados['test_score'].std()
print(f'Intervalo de confiança: [{media - 2*desvio_padrao}, {min(media + 2*desvio_padrao, 1)}]')
# Out:
# Intervalo de confiança: [0.8974930092069496, 0.9179724757243598]

# %% [markdown]
# ### Validação cruzada com recall

# %%
def intervalo_conf(resultados):
    media = resultados['test_score'].mean()
    desvio_padrao = resultados['test_score'].std()
    print(f'Intervalo de confiança: [{media - 2*desvio_padrao}, {min(media + 2*desvio_padrao, 1)}]')

# %%
modelo = DecisionTreeClassifier(max_depth = 10)
kf = KFold(n_splits = 5, shuffle = True, random_state = 5)
cv_resultados = cross_validate(modelo, x, y, cv = kf, scoring = 'recall')
cv_resultados
# Out:
# {'fit_time': array([0.2190094 , 0.20586634, 0.21080422, 0.21392369, 0.20586586]),
#  'score_time': array([0.01052284, 0.00677085, 0.00659442, 0.00657868, 0.01082897]),
#  'test_score': array([0.02642008, 0.01856436, 0.0196802 , 0.0156658 , 0.02543353])}

# %%
intervalo_conf(cv_resultados)
# Out:
# Intervalo de confiança: [0.012904413900403562, 0.029401168041219464]

# %% [markdown]
# ### Estratificando os dados

# %%
dados['inadimplente'].value_counts(normalize = True)
# Out:
# 0    0.912707
# 1    0.087293
# Name: inadimplente, dtype: float64

# %%
from sklearn.model_selection import StratifiedKFold

# %%
modelo = DecisionTreeClassifier(max_depth = 10)
skf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 5)
cv_resultados = cross_validate(modelo, x, y, cv = skf, scoring = 'recall')

# %%
intervalo_conf(cv_resultados)
# Out:
# Intervalo de confiança: [0.01530563507862015, 0.041563428218194]

# %% [markdown]
# ## <font color='dark'>Balanceamento de dados</h1>

# %% [markdown]
# ### Oversampling

# %%
from imblearn.over_sampling import SMOTE

# %%
oversample = SMOTE()
x_balanceado, y_balanceado = oversample.fit_resample(x, y)

# %%
y_balanceado.value_counts(normalize = True)
# Out:
# 0    0.5
# 1    0.5
# Name: inadimplente, dtype: float64

# %%
modelo = DecisionTreeClassifier(max_depth = 10)
skf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 5)
cv_resultados = cross_validate(modelo, x_balanceado, y_balanceado, cv = skf, scoring = 'recall')

# %%
intervalo_conf(cv_resultados)
# Out:
# Intervalo de confiança: [0.7060717112685824, 0.7725966849325785]

# %% [markdown]
# ### Pipeline para validação

# %%
from imblearn.pipeline import Pipeline as imbpipeline

# %%
modelo = DecisionTreeClassifier(max_depth = 10)
pipeline = imbpipeline([('oversample', SMOTE()), ('arvore', modelo)])

# %%
skf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 5)
cv_resultados = cross_validate(pipeline, x, y, cv = skf, scoring = 'recall')

# %%
intervalo_conf(cv_resultados)
# Out:
# Intervalo de confiança: [0.19434095052168057, 0.2875753573353933]

# %% [markdown]
# ### Undersampling

# %%
from imblearn.under_sampling import NearMiss

# %%
modelo = DecisionTreeClassifier(max_depth = 10)
pipeline = imbpipeline([('undersample', NearMiss(version = 3)), ('arvore', modelo)])
skf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 5)
cv_resultados = cross_validate(pipeline, x, y, cv = skf, scoring = 'recall')

# %%
intervalo_conf(cv_resultados)
# Out:
# Intervalo de confiança: [0.6198778536492056, 0.7006329791315145]

# %% [markdown]
# ### Testando o modelo

# %%
undersample = NearMiss(version = 3)
x_balanceado, y_balanceado = undersample.fit_resample(x, y)

modelo = DecisionTreeClassifier(max_depth = 10)
modelo.fit(x_balanceado, y_balanceado)
y_previsto = modelo.predict(x_teste)

print(classification_report(y_teste, y_previsto))
ConfusionMatrixDisplay.from_predictions(y_teste, y_previsto);
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.48      0.64      7397
#            1       0.11      0.70      0.20       707
#
#     accuracy                           0.50      8104
#    macro avg       0.53      0.59      0.42      8104
# weighted avg       0.87      0.50      0.60      8104
